# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import imutils
import os 
cheques = os.listdir('../Images')
cheques = [i for i in cheques if 'jpg' in i]
# cheques
for i in cheques:
    # Load image and HSV color threshold
    image = cv2.imread('../Images/'+i)
    img = np.array(image)
    #resize the image to height of 500 and keep the same aspect ratio
    ratio = img.shape[0]/500.0
    plt.imshow(imutils.resize(img,height=1000))
    image=imutils.resize(img,height=1000)

    x1, y1 = int(1750 ), int(600 )  # Top-left corner
    x2, y2 = int(2000 ), int(800)  # Bottom-right corner

    # Crop the image based on the specified coordinates
    cropped_img = image[y1:y2, x1:x2]

    # Display the cropped image
    cv2.imwrite(i,cropped_img)
    # cv2.imshow('Cropped Image', cropped_img)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import imutils
import os 
cheques = os.listdir('../Images')
cheques = [i for i in cheques if 'jpg' in i]
# cheques

# Load image and HSV color threshold
image = cv2.imread('../Images/'+'Cheque309061.jpg')
img = np.array(image)
# print(image.shape)
#resize the image to height of 500 and keep the same aspect ratio
ratio = img.shape[0]/500.0
plt.imshow(imutils.resize(img,height=1000))
image=imutils.resize(img,height=1000)

x1, y1 = int(1850 ), int(590 )  # Top-left corner
x2, y2 = int(2100 ), int(740)  # Bottom-right corner

cropped_img = image[y1:y2, x1:x2]

plt.imshow(cropped_img)
# cv2.imwrite(i,cropped_img)

# %%
# #converting to grayscale image
# gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# gray = cv2.GaussianBlur(gray,(5,5),0)
# plt.imshow(gray,'gray')
# edged = cv2.Canny(gray,80,200)
# plt.imshow(edged,'gray')
